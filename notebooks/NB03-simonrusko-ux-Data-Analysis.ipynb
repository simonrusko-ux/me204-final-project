# %% [markdown]
# # NB03 — Data Analysis
#
# **Author:** `simonrusko-ux`
#
# [Jednou vetou: na akú otázku tento notebook hľadá odpoveď.]
#
# Tento notebook číta pripravené tabuľky z `NB02` a hľadá v nich patterny.
# Nezbiera dáta a neopakuje prípravu — to je práca NB01 a NB02.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Relatívne cesty, aby notebook bežal aj z čistého clonu.
PROCESSED = Path('..') / 'data' / 'processed'

# %% [markdown]
# ## 1. Load prepared data
#
# [Ktorý súbor načítavam a čo predstavuje jeden riadok tejto tabuľky?]

# %%
# df = pd.read_csv(PROCESSED / '<nazov-suboru>.csv')
# df.head()

# %% [markdown]
# ## 2. Exploration
#
# [Tu skúmam dáta — summaries, filtre, groupby, grafy.
# Môžem preskúmať viac vecí, než nakoniec dám na web.]

# %% [markdown]
# ## 3. Findings
#
# Dve až tri zistenia, ktoré ponesú web stránku. Ku každému musí byť
# vyššie v notebooku vidno výstup, z ktorého vychádza.
#
# ### Finding 1 — [názov]
#
# [Čo konkrétne vidím: konkrétne hodnoty a patterny z MOJICH dát.]
#
# ### Finding 2 — [názov]
#
# [...]
#
# ### Finding 3 — [názov, ak bude]
#
# [...]

# %% [markdown]
# ## 4. Limitations
#
# [Čo dáta nepokrývajú, aké voľby som spravil a ako ovplyvňujú závery.]
